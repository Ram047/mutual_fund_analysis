# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt

conn = sqlite3.connect('../data/bluestock_mf.db')

# %%
import pandas as pd

tables = pd.read_sql("""
SELECT name
FROM sqlite_master
WHERE type='table'
""", conn)

tables
# Out:
#                              name
# 0            02_nav_history_clean
# 1     07_scheme_performance_clean
# 2  08_investor_transactions_clean

# %%
nav = pd.read_sql("""
SELECT * FROM '02_nav_history_clean'
""", conn)

performance = pd.read_sql("""
SELECT * FROM '07_scheme_performance_clean'
""", conn)

transactions = pd.read_sql("""
SELECT * FROM '08_investor_transactions_clean'
""", conn)

# %%
print(nav.shape)
print(performance.shape)
print(transactions.shape)
# Out:
# (46000, 3)
# (40, 19)
# (32778, 13)

# %%
print(nav.columns)
print(performance.columns)
print(transactions.columns)
# Out:
# Index(['amfi_code', 'date', 'nav'], dtype='object')
# Index(['amfi_code', 'scheme_name', 'fund_house', 'category', 'plan',
#        'return_1yr_pct', 'return_3yr_pct', 'return_5yr_pct',
#        'benchmark_3yr_pct', 'alpha', 'beta', 'sharpe_ratio', 'sortino_ratio',
#        'std_dev_ann_pct', 'max_drawdown_pct', 'aum_crore', 'expense_ratio_pct',
#        'morningstar_rating', 'risk_grade'],
#       dtype='object')
# Index(['investor_id', 'transaction_date', 'amfi_code', 'transaction_type',
#        'amount_inr', 'state', 'city', 'city_tier', 'age_group', 'gender',
#        'annual_income_lakh', 'payment_mode', 'kyc_status'],
#       dtype='object')

# %%
nav.head()
# Out:
#    amfi_code        date       nav
# 0     100016  2022-01-03  520.4608
# 1     100016  2022-01-04  515.0971
# 2     100016  2022-01-05  521.7239
# 3     100016  2022-01-06  515.7880
# 4     100016  2022-01-07  515.1639

# %%
performance.head()
# Out:
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth  SBI Mutual Fund
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth  SBI Mutual Fund
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth  SBI Mutual Fund
#
#     category     plan  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0  Large Cap  Regular           12.42           12.36           14.45
# 1  Large Cap   Direct           15.25           11.30           14.23
# 2  Small Cap  Regular           24.56           23.39           20.67
# 3  Small Cap   Direct           20.59           23.14           21.82
# 4       Gilt  Regular            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# ...

# %%
transactions.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              Sip        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              Sip         912
# 3   INV003436       2024-01-01     118634              Sip        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
nav.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  object
#  2   nav        46000 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
nav['date'] = pd.to_datetime(nav['date'])

nav = nav.sort_values(
    ['amfi_code', 'date']
)

# %%
nav['daily_return'] = (
    nav.groupby('amfi_code')['nav']
       .pct_change()
)

# %%
nav.head(10)
# Out:
#    amfi_code       date       nav  daily_return
# 0     100016 2022-01-03  520.4608           NaN
# 1     100016 2022-01-04  515.0971     -0.010306
# 2     100016 2022-01-05  521.7239      0.012865
# 3     100016 2022-01-06  515.7880     -0.011377
# 4     100016 2022-01-07  515.1639     -0.001210
# 5     100016 2022-01-10  510.7136     -0.008639
# 6     100016 2022-01-11  513.5542      0.005562
# 7     100016 2022-01-12  512.3195     -0.002404
# 8     100016 2022-01-13  510.2445     -0.004050
# 9     100016 2022-01-14  514.3636      0.008073

# %%
var_results = []

for code, grp in nav.groupby('amfi_code'):

    returns = grp['daily_return'].dropna()

    var95 = np.percentile(
        returns,
        5
    )

    cvar95 = returns[
        returns <= var95
    ].mean()

    var_results.append({
        'amfi_code': code,
        'VaR_95': var95,
        'CVaR_95': cvar95
    })

var_df = pd.DataFrame(
    var_results
)

var_df.head()
# Out:
#    amfi_code    VaR_95   CVaR_95
# 0     100016 -0.014364 -0.018060
# 1     100025 -0.003793 -0.004994
# 2     100033 -0.019034 -0.023456
# 3     101206 -0.013282 -0.017439
# 4     101207 -0.026021 -0.032459

# %%
var_df.to_csv(
    '../outputs/var_cvar_report.csv',
    index=False
)

print("Saved Successfully")
# Out:
# Saved Successfully

# %%
performance.columns
# Out:
# Index(['amfi_code', 'scheme_name', 'fund_house', 'category', 'plan',
#        'return_1yr_pct', 'return_3yr_pct', 'return_5yr_pct',
#        'benchmark_3yr_pct', 'alpha', 'beta', 'sharpe_ratio', 'sortino_ratio',
#        'std_dev_ann_pct', 'max_drawdown_pct', 'aum_crore', 'expense_ratio_pct',
#        'morningstar_rating', 'risk_grade'],
#       dtype='object')

# %%
top5 = (
    performance
    .sort_values(
        'sharpe_ratio',
        ascending=False
    )
    .head(5)
)

top5
# Out:
#     amfi_code                                   scheme_name  \
# 14     120507      ICICI Pru Liquid Fund - Regular - Growth
# 23     120844          Kotak Liquid Fund - Regular - Growth
# 30     101208           ABSL Liquid Fund - Regular - Growth
# 9      100025  HDFC Short Term Debt Fund - Regular - Growth
# 4      119120  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#                   fund_house        category     plan  return_1yr_pct  \
# 14       ICICI Prudential MF          Liquid  Regular            8.89
# 23         Kotak Mahindra MF          Liquid  Regular            4.26
# 30  Aditya Birla Sun Life MF          Liquid  Regular            6.18
# 9           HDFC Mutual Fund  Short Duration  Regular            6.83
# 4            SBI Mutual Fund            Gilt  Regular            5.34
#
#     return_3yr_pct  return_5yr_pct  benchmark_3yr_pct  alpha  beta  \
# 14            7.68            7.94               5.83   1.85  0.26
# ...

# %%
def rolling_sharpe(returns, window=90):

    return (
        returns.rolling(window).mean()
        /
        returns.rolling(window).std()
    ) * np.sqrt(252)

# %%
plt.figure(figsize=(12,6))

for code in top5['amfi_code']:

    temp = nav[
        nav['amfi_code'] == code
    ]

    rs = rolling_sharpe(
        temp['daily_return']
    )

    plt.plot(
        temp['date'],
        rs,
        label=str(code)
    )

plt.title(
    'Rolling 90-Day Sharpe Ratio'
)

plt.xlabel('Date')
plt.ylabel('Sharpe Ratio')

plt.legend()

plt.show()

# %%
plt.figure(figsize=(12,6))

for code in top5['amfi_code']:

    temp = nav[
        nav['amfi_code'] == code
    ]

    rs = rolling_sharpe(
        temp['daily_return']
    )

    plt.plot(
        temp['date'],
        rs,
        label=str(code)
    )

plt.legend()

plt.savefig(
    '../outputs/rolling_sharpe_chart.png'
)

print("Chart Saved Successfully")
# Out:
# Chart Saved Successfully

# %%
transactions['transaction_date'] = pd.to_datetime(
    transactions['transaction_date']
)

# %%
first_txn = (
    transactions
    .groupby('investor_id')
    ['transaction_date']
    .min()
)

# %%
transactions = transactions.merge(
    first_txn.rename('first_date'),
    on='investor_id'
)

transactions['cohort_year'] = (
    transactions['first_date']
    .dt.year
)

# %%
cohort = (
    transactions
    .groupby('cohort_year')
    .agg(
        avg_sip_amount=('amount_inr','mean'),
        total_invested=('amount_inr','sum'),
        investors=('investor_id','nunique')
    )
    .reset_index()
)

cohort
# Out:
#    cohort_year  avg_sip_amount  total_invested  investors
# 0         2024   107422.541832      3491125187       4803
# 1         2025   109158.577061        30455243        197

# %%
cohort.to_csv(
    '../outputs/cohort_analysis.csv',
    index=False
)

print("Cohort report saved")
# Out:
# Cohort report saved

# %%
sip = transactions[
    transactions['transaction_type'] == 'SIP'
].copy()

# %%
sip = sip.sort_values(
    ['investor_id','transaction_date']
)

# %%
sip['gap_days'] = (
    sip.groupby('investor_id')
       ['transaction_date']
       .diff()
       .dt.days
)

# %%
sip_gap['status'] = np.where(
    sip_gap['gap_days'] > 35,
    'At Risk',
    'Active'
)

sip_gap.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 sip_gap['status'] = np.where(
# ----> 2     sip_gap['gap_days'] > 35,
#       3     'At Risk',
#       4     'Active'
#       5 )
#       7 sip_gap.head()
#
# NameError: name 'sip_gap' is not defined

# %%
sip.head()
# Out:
# Empty DataFrame
# Columns: [investor_id, transaction_date, amfi_code, transaction_type, amount_inr, state, city, city_tier, age_group, gender, annual_income_lakh, payment_mode, kyc_status, first_date, cohort_year, gap_days]
# Index: []

# %%
sip.columns
# Out:
# Index(['investor_id', 'transaction_date', 'amfi_code', 'transaction_type',
#        'amount_inr', 'state', 'city', 'city_tier', 'age_group', 'gender',
#        'annual_income_lakh', 'payment_mode', 'kyc_status', 'first_date',
#        'cohort_year', 'gap_days'],
#       dtype='object')

# %%
sip_gap = (
    sip.groupby('investor_id')
       ['gap_days']
       .mean()
       .reset_index()
)

sip_gap.head()
# Out:
# Empty DataFrame
# Columns: [investor_id, gap_days]
# Index: []

# %%
sip_gap['status'] = np.where(
    sip_gap['gap_days'] > 35,
    'At Risk',
    'Active'
)

sip_gap.head()
# Out:
# Empty DataFrame
# Columns: [investor_id, gap_days, status]
# Index: []

# %%
performance.columns
# Out:
# Index(['amfi_code', 'scheme_name', 'fund_house', 'category', 'plan',
#        'return_1yr_pct', 'return_3yr_pct', 'return_5yr_pct',
#        'benchmark_3yr_pct', 'alpha', 'beta', 'sharpe_ratio', 'sortino_ratio',
#        'std_dev_ann_pct', 'max_drawdown_pct', 'aum_crore', 'expense_ratio_pct',
#        'morningstar_rating', 'risk_grade'],
#       dtype='object')

# %% [markdown]
# The fund with the highest VaR (95%) exhibited the largest downside risk.

# %%
risk = "Moderate"   # Change to Low / Moderate / High

recommendations = (
    performance[
        performance['risk_grade'] == risk
    ]
    .sort_values(
        'sharpe_ratio',
        ascending=False
    )
    .head(3)
)

recommendations[
    [
        'scheme_name',
        'risk_grade',
        'sharpe_ratio',
        'return_3yr_pct'
    ]
]
# Out:
#                                       scheme_name risk_grade  sharpe_ratio  \
# 5       HDFC Top 100 Fund - Regular Plan - Growth   Moderate          1.06
# 34  Mirae Asset Large Cap Fund - Regular - Growth   Moderate          1.06
# 11      ICICI Pru Bluechip Fund - Direct - Growth   Moderate          1.03
#
#     return_3yr_pct
# 5            14.84
# 34           14.81
# 11           14.41

# %% [markdown]
#  CVaR analysis identified the fund with the highest tail-risk exposure.

# %%
recommendations.to_csv(
    '../outputs/recommendations.csv',
    index=False
)

print("Recommendations saved")
# Out:
# Recommendations saved

# %% [markdown]
#  The top investor cohort contributed the largest total investment amount.

# %%
pd.read_sql("""
SELECT name
FROM sqlite_master
WHERE type='table'
""", conn)
# Out:
#                              name
# 0            02_nav_history_clean
# 1     07_scheme_performance_clean
# 2  08_investor_transactions_clean

# %% [markdown]
# SIP continuity analysis identified active and at-risk investors based on average investment gaps.
# The fund with the highest Sharpe Ratio delivered the best risk-adjusted performance.
